# %%
# Humanクラスの定義
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def check_adult(self):
        if self.age >= 20:
            print(f"{self.name}さんは大人です")
        else:
            print(f"{self.name}さんは大人ではありません")


# インスタンスを複数生成
human_list = [
    Human("太郎", 25),
    Human("花子", 18),
    Human("健一", 30),
    Human("さゆり", 15)
]

# リスト内のすべてのインスタンスに対してcheck_adultメソッドを実行
for human in human_list:
    human.check_adult()
# Out:
# 太郎さんは大人です
# 花子さんは大人ではありません
# 健一さんは大人です
# さゆりさんは大人ではありません
